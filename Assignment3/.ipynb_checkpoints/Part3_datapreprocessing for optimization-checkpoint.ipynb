# %%
import sys
import SimpleITK as sitk
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
# %matplotlib inline 
import numpy as np
import os
import fnmatch
import shutil
from ipywidgets import interact, fixed
import pandas as pd
import warnings
from skimage import exposure
from skimage import data
from skimage.transform import rotate
import _pickle as cPickle
import random


def myshow(image_arr,slice_n):
    plt.imshow(image_arr[slice_n,:,:],cmap='gray')
    plt.show()

# %%
#reading corresponding dataframes with arrays 

t2_df=pd.read_pickle('./t2_augmented.pkl')
adc_df=pd.read_pickle('./adc_augmented.pkl')
bval_df=pd.read_pickle('./bval_augmented.pkl')
ktrans_df=pd.read_pickle('./ktrans_augmented.pkl')

# %%
#function to get zero-mean unit variance 

def get_optimized(data):
    
    for i in range(len(data)):
        array = data.loc[i, 'patches']
        optimized = (array - array.mean(axis=0)) / array.std(axis=0)
        data.at[i, 'patches']=optimized
    return data


t2_o = get_optimized(t2_df)    
adc_o = get_optimized(adc_df)
bval_o = get_optimized(bval_df)
ktrans_o = get_optimized(ktrans_df)
# Out:
# /home/andrii/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
"""
Once we have all data optimized it is time to get all our images to arrays
For that we can write a simple function 
"""
#Get array of images from column
def get_array(data, column='patches'):

# %%
#once we get adequately balanced datasets we can right them top the disk fopr further analysis




t2_o.to_pickle('./t2_optimized.pkl')
adc_o.to_pickle('./adc_optimized.pkl')
bval_o.to_pickle('./bval_optimized.pkl')
ktrans_o.to_pickle('./ktrans_optimized.pkl')

# %%
#After Optimization It is good idea to create arrays of images, which we are going to use in the nearest future for training and validation

# %%
x_train= t2_o.patches.as_matrix(columns=None)
y_train= t2_o.ClinSig.as_matrix(columns=None)
# Out:
# /home/andrii/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# /home/andrii/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
def choose_for_model(data, columns=['ClinSig', 'patches']):
    x=data[columns[1]].as_matrix(columns=None)
    y=data[columns[0]].as_matrix(columns=None)
    return x, y

# %%
from sklearn.model_selection import train_test_split #GREAT for model selection!!!!!!!!

train, test = train_test_split(t2_o, test_size=0.2)

x_train, y_train = choose_for_model(train)
x_test, y_test = choose_for_model(test)
# Out:
# /home/andrii/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /home/andrii/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x_train.shape
# Out:
# (601,)

# %%
images.T.reshape(60000,28*28)

# %%
a=x_train.reshape(x_train.shape[0], 32, 32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-df45ca0dd64a> in <module>
# ----> 1 a=x_train.reshape(x_train.shape[0], 32, 32)
#
# ValueError: cannot reshape array of size 601 into shape (601,32,32)

# %%
data = np.array([i*np.ones((5,5,3)) for i in range(10)], dtype=np.float64)

# %%
data= np.array([i for i in t2_o.patches])

# %%
for i in x_train:
    print(i.shape)
    i=i.reshape(32, 32)
# Out:
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)

# %%
x_train.shape
# Out:
# (601,)
